# %%
import numpy as np

# %%
gfg=np.array([[4,1,9],[12,3,1],[4,5,6]])

print(np.sum(gfg))

print(np.sum(gfg,axis=0))  #sum of columns

print(np.sum(gfg,axis=1))  #sum of rows
# Out:
# 45
# [20  9 16]
# [14 16 15]

# %%
array=np.array([10, 52, 62, 16, 16, 54, 453])

print(np.sort(array))
print(np.argsort(array))

array1=np.sort(array)
print(array1[0:4])

print(array1[-5:])
# Out:
# [ 10  16  16  52  54  62 453]
# [0 3 4 1 5 2 6]
# [10 16 16 52]
# [ 16  52  54  62 453]

# %%
arr = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])
integer=[]
float1=[]
i=0
for i in range(len(arr)):
    if arr[i].is_integer():
        integer.append(arr[i])
    else:
        float1.append(arr[i])

print(integer)
print(float1)
# Out:
# [np.float64(1.0), np.float64(2.0), np.float64(3.0), np.float64(2.0)]
# [np.float64(1.2), np.float64(2.2)]

# %%
import numpy as np
import matplotlib.pyplot as plt
new_arr=np.linspace(-10,10,100)


squared=new_arr*new_arr
plt.plot(new_arr,squared)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Plot of x^2")
plt.legend()
plt.grid()
plt.show()

sined=np.sin(new_arr)
plt.plot(new_arr,sined)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Plot of sinx")
plt.legend()
plt.grid()
plt.show()


exp_values = np.exp(new_arr)
plt.figure(figsize=(8, 4))
plt.plot(new_arr, exp_values, label="e^x", color="green")
plt.xlabel("x")
plt.ylabel("e^x")
plt.title("Plot of e^x")
plt.legend()
plt.grid()
plt.show()

logged_values=np.log(new_arr+1)
plt.figure(figsize=(8, 4))
plt.plot(new_arr, exp_values, label="log(|x|+1)", color="green")
plt.xlabel("x")
plt.ylabel("e^x")
plt.title("Plot of function")
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9096\515537560.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9096\515537560.py:20: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9096\515537560.py:35: RuntimeWarning: invalid value encountered in log
#   logged_values=np.log(new_arr+1)
