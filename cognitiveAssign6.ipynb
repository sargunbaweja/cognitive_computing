# %%
import numpy as np
import matplotlib.pyplot as plt
M=float(input("enter M: "))
x=np.linspace(-10,10,100)
y1=M*x*x
y2=M*np.sin(x)
plt.plot(x,y1, 'g', label='y=M*x^2')
plt.plot(x,y2,'r--',label='y=M*sin(x)')
plt.legend()
plt.grid()
plt.show()
# Out:
# enter M:  6

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

subjects = ['dbms', 'dms', 'ai', 'cc', 'probstats']
scores = [85, 90, 78, 88, 95]
data = pd.DataFrame({'Subject': subjects, 'Score': scores})

plt.figure(figsize=(8, 6))
barplot = sns.barplot(x='Subject', y='Score', data=data)

for i, score in enumerate(scores):
    barplot.text(i, score + 1, str(score), ha='center', va='bottom')

plt.title('Subject Scores')
plt.xlabel('Subjects')
plt.ylabel('Scores')


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

rollno = int(input("Enter roll no: "))
np.random.seed(rollno)

data = np.random.randn(50)

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

axs[0, 0].plot(np.cumsum(data), marker='o', linestyle='-', color='red')
axs[0, 0].set_title("Cumulative sum plot")
axs[0, 0].set_xlabel("Index")
axs[0, 0].set_ylabel("Cumulative sum")
axs[0, 0].grid(True)

x_noise = np.arange(50)
y_noise = data + np.random.normal(0, 0.5, 50)
axs[0, 1].scatter(x_noise, y_noise, color='red', marker='x')
axs[0, 1].set_title("Scatter Plot with Noise")
axs[0, 1].set_xlabel("Index")
axs[0, 1].set_ylabel("Value + Noise")
axs[0, 1].grid(True)

axs[1, 0].axis("off")
axs[1, 1].axis("off")

plt.show()
# Out:
# Enter roll no:  196

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\LENOVO\Downloads\company_sales_data.csv")

plt.figure(figsize=(8, 6))
plt.plot(data['month_number'], data['total_profit'], marker='o', linestyle='-', color='blue')
plt.title('Total Profit Over Months')
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 8))
for column in data.columns[1:-1]: 
    plt.plot(data['month_number'], data[column], marker='o', label=column)

plt.title('Product Sales Over Months')
plt.xlabel('Month Number')
plt.ylabel('Units Sold')
plt.legend()
plt.grid(True)
plt.show()

data.plot(kind='bar', figsize=(12, 8))
plt.title('Bar Plot for All Features')
plt.xlabel('Month Index')
plt.ylabel('Values')
plt.grid(True, linestyle='--')
plt.show()
